# %%
import numpy as np
import pandas as pd
import scipy
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import cufflinks as cf

# %%
init_notebook_mode(connected=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
cf.go_offline()
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.

# %%
movie = pd.read_csv('tmdb_5000_movies.csv')
movies = movie[['title','release_date','budget','revenue','runtime','popularity','vote_average','vote_count']]
movies.head(8)
# Out:
#                                       title release_date     budget  \
# 0                                    Avatar   2009-12-10  237000000
# 1  Pirates of the Caribbean: At World's End   2007-05-19  300000000
# 2                                   Spectre   2015-10-26  245000000
# 3                     The Dark Knight Rises   2012-07-16  250000000
# 4                               John Carter   2012-03-07  260000000
# 5                              Spider-Man 3   2007-05-01  258000000
# 6                                   Tangled   2010-11-24  260000000
# 7                   Avengers: Age of Ultron   2015-04-22  280000000
#
#       revenue  runtime  popularity  vote_average  vote_count
# 0  2787965087    162.0  150.437577           7.2       11800
# 1   961000000    169.0  139.082615           6.9        4500
# 2   880674609    148.0  107.376788           6.3        4466
# 3  1084939099    165.0  112.312950           7.6        9106
# ...

# %%
movies.shape
# Out:
# (4803, 8)

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 8 columns):
# title           4803 non-null object
# release_date    4802 non-null object
# budget          4803 non-null int64
# revenue         4803 non-null int64
# runtime         4801 non-null float64
# popularity      4803 non-null float64
# vote_average    4803 non-null float64
# vote_count      4803 non-null int64
# dtypes: float64(3), int64(3), object(2)
# memory usage: 300.3+ KB

# %% [markdown]
# ## About this data set
# This data set was scraped from the webpage Imdb.  It is the break down of just under 5000 movies. I have removed a handful of columns to focus on specific data.
#
# ## Hypotheses
#
# 1) How does popularity affect revenue and vote_average
#
# 2) How does the release date affect the budget and vote_average
#
# 3) How is vote_average effected by runtime
#
# 4) Last, how does budget affect runtime

# %%
movies['vote_average'].iplot(kind='hist',bins=200)
# Out:
# <div id="94ab009c-f698-4c93-858c-38823044feb5" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("94ab009c-f698-4c93-858c-38823044feb5", [{"type": "histogram", "x": [7.2, 6.9, 6.3, 7.6, 6.1, 5.9, 7.4, 7.3, 7.4, 5.7, 5.4, 6.1, 7.0, 5.9, 6.5, 6.3, 7.4, 6.4, 6.2, 7.1, 6.5, 6.2, 7.6, 5.8, 6.6, 7.5, 7.1, 5.5, 6.5, 6.9, 6.7, 6.8, 6.4, 6.3, 7.0, 6.0, 5.8, 5.7, 6.5, 6.3, 5.8, 5.1, 7.6, 5.9, 7.3, 6.7, 7.5, 7.4, 5.5, 7.3, 6.2, 6.7, 6.1, 5.7, 6.6, 6.7, 6.6, 7.8, 6.1, 5.6, 6.6, 5.2, 5.5, 6.7, 6.4, 8.2, 7.7, 6.0, 7.4, 7.0, 5.1, 5.2, 5.9, 5.3, 7.6, 5.9, 5.6, 8.0, 6.7, 6.6, 5.8, 7.0, 7.3, 4.8, 5.9, 7.6, 6.0, 6.2, 7.8, 7.1, 6.4, 4.9, 7.5, 5.9, 7.9, 8.1, 8.1, 6.5, 7.0, 6.6, 7.3, 7.1, 6.6, 5.8, 5.5, 6.5, 6.0, 6.3, 5.8, 6.2, 6.6, 6.6, 5.6, 7.4, 7.5, 6.2, 6.9, 6.7, 7.5, 7.5, 6.2, 5.9, 6.2, 6.4, 7.3, 6.7, 6.8, 7.2, 6.5, 6
# ...

# %%
movies.iplot(kind='bubble',x='budget',y='revenue',size='popularity')
# Out:
# <div id="4b37f817-6c17-4f0e-81cd-307a25f38a79" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("4b37f817-6c17-4f0e-81cd-307a25f38a79", [{"type": "scatter", "x": [237000000, 300000000, 245000000, 250000000, 260000000, 258000000, 260000000, 280000000, 250000000, 250000000, 270000000, 200000000, 200000000, 255000000, 225000000, 225000000, 220000000, 380000000, 225000000, 250000000, 215000000, 200000000, 250000000, 180000000, 207000000, 200000000, 250000000, 209000000, 150000000, 200000000, 200000000, 200000000, 200000000, 210000000, 200000000, 150000000, 210000000, 200000000, 200000000, 170000000, 200000000, 200000000, 200000000, 200000000, 190000000, 200000000, 250000000, 190000000, 195000000, 105000000, 150000000, 180000000, 195000000, 185000000, 175000000, 185000000, 185000000, 180000000, 140000000,
# ...

# %%
movies.iplot(kind='scatter', x='runtime',y='vote_average',mode='markers')
# Out:
# <div id="03175fc9-4632-4f37-b69e-0fcae0848b8d" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("03175fc9-4632-4f37-b69e-0fcae0848b8d", [{"type": "scatter", "x": [162.0, 169.0, 148.0, 165.0, 132.0, 139.0, 100.0, 141.0, 153.0, 151.0, 154.0, 106.0, 151.0, 149.0, 143.0, 150.0, 143.0, 136.0, 106.0, 144.0, 136.0, 140.0, 161.0, 113.0, 187.0, 194.0, 147.0, 131.0, 124.0, 143.0, 127.0, 130.0, 108.0, 104.0, 104.0, 150.0, 165.0, 130.0, 142.0, 125.0, 106.0, 114.0, 103.0, 115.0, 137.0, 116.0, 131.0, 132.0, 114.0, 143.0, 116.0, 131.0, 154.0, 122.0, 93.0, 93.0, 122.0, 98.0, 91.0, 158.0, 96.0, 124.0, 109.0, 143.0, 144.0, 152.0, 96.0, 94.0, 126.0, 126.0, 106.0, 112.0, 123.0, 96.0, 113.0, 135.0, 118.0, 94.0, 106.0, 124.0, 127.0, 97.0, 130.0, 109.0, 119.0, 136.0, 93.0, 130.0, 102.0, 108.0, 100.0, 120.0, 98.0, 109.0, 12
# ...

# %%
movies.iplot(kind='bar',x= 'vote_average', y = 'runtime')
# Out:
# <div id="2d21d631-1a19-454e-8a53-aec304174436" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("2d21d631-1a19-454e-8a53-aec304174436", [{"type": "bar", "x": [7.2, 6.9, 6.3, 7.6, 6.1, 5.9, 7.4, 7.3, 7.4, 5.7, 5.4, 6.1, 7.0, 5.9, 6.5, 6.3, 7.4, 6.4, 6.2, 7.1, 6.5, 6.2, 7.6, 5.8, 6.6, 7.5, 7.1, 5.5, 6.5, 6.9, 6.7, 6.8, 6.4, 6.3, 7.0, 6.0, 5.8, 5.7, 6.5, 6.3, 5.8, 5.1, 7.6, 5.9, 7.3, 6.7, 7.5, 7.4, 5.5, 7.3, 6.2, 6.7, 6.1, 5.7, 6.6, 6.7, 6.6, 7.8, 6.1, 5.6, 6.6, 5.2, 5.5, 6.7, 6.4, 8.2, 7.7, 6.0, 7.4, 7.0, 5.1, 5.2, 5.9, 5.3, 7.6, 5.9, 5.6, 8.0, 6.7, 6.6, 5.8, 7.0, 7.3, 4.8, 5.9, 7.6, 6.0, 6.2, 7.8, 7.1, 6.4, 4.9, 7.5, 5.9, 7.9, 8.1, 8.1, 6.5, 7.0, 6.6, 7.3, 7.1, 6.6, 5.8, 5.5, 6.5, 6.0, 6.3, 5.8, 6.2, 6.6, 6.6, 5.6, 7.4, 7.5, 6.2, 6.9, 6.7, 7.5, 7.5, 6.2, 5.9, 6.2, 6.4, 7.3, 6.7, 6.8, 7.2, 6.5, 6.6, 6.
# ...

# %%
movies.iplot(kind='scatter', x='runtime',y='budget',mode='markers')
# Out:
# <div id="2e42c785-fa21-445a-ac9a-aa9b106feacc" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("2e42c785-fa21-445a-ac9a-aa9b106feacc", [{"type": "scatter", "x": [162.0, 169.0, 148.0, 165.0, 132.0, 139.0, 100.0, 141.0, 153.0, 151.0, 154.0, 106.0, 151.0, 149.0, 143.0, 150.0, 143.0, 136.0, 106.0, 144.0, 136.0, 140.0, 161.0, 113.0, 187.0, 194.0, 147.0, 131.0, 124.0, 143.0, 127.0, 130.0, 108.0, 104.0, 104.0, 150.0, 165.0, 130.0, 142.0, 125.0, 106.0, 114.0, 103.0, 115.0, 137.0, 116.0, 131.0, 132.0, 114.0, 143.0, 116.0, 131.0, 154.0, 122.0, 93.0, 93.0, 122.0, 98.0, 91.0, 158.0, 96.0, 124.0, 109.0, 143.0, 144.0, 152.0, 96.0, 94.0, 126.0, 126.0, 106.0, 112.0, 123.0, 96.0, 113.0, 135.0, 118.0, 94.0, 106.0, 124.0, 127.0, 97.0, 130.0, 109.0, 119.0, 136.0, 93.0, 130.0, 102.0, 108.0, 100.0, 120.0, 98.0, 109.0, 12
# ...

# %%
movies.iplot(kind='scatter', x='release_date', y='vote_average',mode='markers')
# Out:
# <div id="aaff8bfe-aa4e-4e2d-8a6d-b70f004d90f7" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("aaff8bfe-aa4e-4e2d-8a6d-b70f004d90f7", [{"type": "scatter", "x": ["2009-12-10", "2007-05-19", "2015-10-26", "2012-07-16", "2012-03-07", "2007-05-01", "2010-11-24", "2015-04-22", "2009-07-07", "2016-03-23", "2006-06-28", "2008-10-30", "2006-06-20", "2013-07-03", "2013-06-12", "2008-05-15", "2012-04-25", "2011-05-14", "2012-05-23", "2014-12-10", "2012-06-27", "2010-05-12", "2013-12-11", "2007-12-04", "2005-12-14", "1997-11-18", "2016-04-27", "2012-04-11", "2015-06-09", "2012-10-25", "2004-06-25", "2013-04-18", "2010-03-03", "2006-05-24", "2013-06-20", "2009-06-19", "2014-06-25", "2013-03-07", "2014-04-16", "2010-12-10", "2011-06-11", "2011-06-16", "2010-06-16", "2009-05-20", "2015-04-01", "2013-06-20", "201
# ...
